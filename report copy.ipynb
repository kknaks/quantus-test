# %%
# !pip install beautifulsoup4
# !pip install requests
# !pip install pandas
# !pip install tqdm
# Out:
# Requirement already satisfied: beautifulsoup4 in ./.conda/lib/python3.11/site-packages (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in ./.conda/lib/python3.11/site-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./.conda/lib/python3.11/site-packages (from beautifulsoup4) (4.14.1)
# Requirement already satisfied: requests in ./.conda/lib/python3.11/site-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.conda/lib/python3.11/site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.conda/lib/python3.11/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.conda/lib/python3.11/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.conda/lib/python3.11/site-packages (from requests) (2025.6.15)
# Requirement already satisfied: pandas in ./.conda/lib/python3.11/site-packages (2.3.0)
# Requirement already satisfied: numpy>=1.23.2 in ./.conda/lib/python3.11/site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.conda/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.conda/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.conda/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in ./.conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: tqdm in ./.conda/lib/python3.11/site-packages (4.67.1)

# %%
# 요약보기
pd.set_option('display.max_rows', 100)

# %%
#전체행 보기 
pd.set_option('display.max_rows', None)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm
import re

# %% [markdown]
# # 저평가 중소형주 발굴을 통한 투자 전략 수립

# %% [markdown]
# ## 1. 중소형주 후보군 선정
# ### 1) 선정기준
# - 전체 상장 종목(코스피 + 코스닥) 중 시가총액 하위 30% 추출
# - 중소형주 중 최근 1년 수익률 상위 100개 추출

# %% [markdown]
# ### 2) 시가 총액 하위 30% 추출
# #### - 네이버 증권에서 시가 총액 기준으로 크롤링

# %%
base_url = "https://finance.naver.com/sise/sise_market_sum.naver"
field_url = "https://finance.naver.com/sise/field_submit.naver"
socks = [0,1]


fields = {'fieldIds': []}

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Referer': 'https://finance.naver.com/sise/sise_market_sum.naver'
}

session = requests.Session()
session.post(field_url, data=fields, headers=headers)

all_data = []
columns = None
for sosok in tqdm(socks):
  page = 1
  while True:
      response = session.get(f"{base_url}?sosok={sosok}&page={page}", headers=headers)
      response.encoding = 'euc-kr'

      soup = BeautifulSoup(response.text, 'html.parser')
      table = soup.find('table', {'class': 'type_2'})
      
      if page == 1:  # 첫 페이지에서만 컬럼명 가져오기
        columns = []
        for th in table.select('thead th'):
            column = th.text.strip()
            if column:
                columns.append(column)
        columns.append('시장구분')
      
      # 데이터 추출
      page_data = []
      for tr in table.select('tbody tr'):
          row = []
          for td in tr.select('td'):
              value = td.text.strip()
              row.append(value)
          if row and len(row) > 1:  # 빈 행과 구분선 제외
              market_type = "kospi" if sosok == 0 else "kosdaq"
              row.append(market_type)
              page_data.append(row)

      
      # 페이지에 데이터가 없으면 종료
      if not page_data:
          break
          
      all_data.extend(page_data)
      page += 1

  # 전체 데이터를 DataFrame으로 변환
df = pd.DataFrame(all_data, columns=columns)
df['시가총액'] = df['시가총액'].apply(lambda x: int(x.replace(',', '')))
df['거래량'] = df['거래량'].apply(lambda x: int(x.replace(',', '')) if x else 0)
kospi_data = df.loc[df['시장구분'] == 'kospi']
kosdaq_data = df.loc[df['시장구분'] == 'kosdaq']

print(f"kospi_data: {len(kospi_data)}")
print(f"kosdaq_data: {len(kosdaq_data)}")

# 선택한 열만 필터링하고 시가총액 기준으로 정렬
selected_data = df.filter(items=['종목명', '시가총액', '거래량', '시장구분'])
sorted_data = selected_data.sort_values(by='시가총액', ascending=True)

# # CSV 파일로 저장
df.to_csv('stocks_market_cap.csv', index=False, encoding='utf-8-sig')
# Out:
# 100%|██████████| 2/2 [00:05<00:00,  2.91s/it]
# kospi_data: 2336
# kosdaq_data: 1798

# %%
df = pd.read_csv('stocks_market_cap.csv', encoding='utf-8-sig')

# %% [markdown]
# #### - ETF, ETN, 지수추종, 우선주 등 종목 필터링

# %%
# ETF 관련 키워드
filter_ETF = [
    "TIGER", "KODEX", "HANARO", "ARIRANG", 
    "KBSTAR", "KOSEF", "SOL", "BNK", 
    "PLUS", "WON", "FOCUS", "KIWOOM", "ACE",
    "KoAct", "액티브", "S&P", "TREX", "ITF", "나스닥",
    "밸류업", "(H)", "마이티", "코스피"
]

# 인버스/레버리지 관련 키워드
filter_inverse_leverage = [
    "인버스", "레버리지", "선물", "ETN", "RISE"
]

# 우선주/전환사채 관련 키워드
filter_preferred = [
    "우선주", "우B", "전환사채"
]

# 기타 제외할 키워드
filter_etc = [
    "스팩", "리츠", "배당"
]

# 전체 필터링 키워드 통합
filter_keyword = list(set(
    filter_ETF + 
    filter_inverse_leverage + 
    filter_preferred + 
    filter_etc
))


keyword_filtered = sorted_data[~sorted_data['종목명'].apply(lambda x: 
    any(keyword in x for keyword in filter_keyword) or 
    bool(re.search(r'우$', x)) or
    bool(re.search(r'^HK', x))

)]
# 상위 30%의 종목만 필터링
keyword_filtered = keyword_filtered.iloc[0:int(len(sorted_data)*0.3)]

# %% [markdown]
# #### - 거래량 필터링

# %%
# 거래량 기본 통계 확인
filtered_data = keyword_filtered[keyword_filtered['거래량'].apply(lambda x : x != 0)]

volume_stats = {
    '최대 거래량': filtered_data['거래량'].max(),
    '최소 거래량': filtered_data['거래량'].min(),
    '평균 거래량': filtered_data['거래량'].mean(),
    '중간값': filtered_data['거래량'].median(),
    '표준편차': filtered_data['거래량'].std()
}

# 결과 출력
for key, value in volume_stats.items():
    print(f"{key}: {value:,.0f}")

# 거래량 분포 확인 (사분위수)
print("\n사분위수 분포:")
print(filtered_data['거래량'].describe())

# 중앙값 이상이면서 상위 95%에 해당하는 종목 필터링
volume_filtered = filtered_data[
    (filtered_data['거래량'] >= filtered_data['거래량'].quantile(0.5)) &
    (filtered_data['거래량'] <= filtered_data['거래량'].quantile(0.95)) 
]
volume_filtered
# Out:
# 최대 거래량: 229,656,889
# 최소 거래량: 77
# 평균 거래량: 752,033
# 중간값: 49,288
# 표준편차: 7,949,013
#
# 사분위수 분포:
# count    1.168000e+03
# mean     7.520326e+05
# std      7.949013e+06
# min      7.700000e+01
# 25%      1.967200e+04
# 50%      4.928850e+04
# 75%      1.500762e+05
# max      2.296569e+08
# Name: 거래량, dtype: float64
#           종목명  시가총액     거래량    시장구분
# 4063      지엔코   127  167374  kosdaq
# 4057     빌리언스   131  194418  kosdaq
# 4052     인베니아   141   52728  kosdaq
# 4044      더코디   149   86007  kosdaq
# 4038   비케이홀딩스   162   87205  kosdaq
# ...       ...   ...     ...     ...
# 3036       빅텍  1180  146380  kosdaq
# 3035    한빛레이저  1185  128175  kosdaq
# 3030   다산네트웍스  1186  140104  kosdaq
# 3032  한선엔지니어링  1186   91677  kosdaq
# 936      KTcs  1197  114317   kospi
#
# [525 rows x 4 columns]

# %% [markdown]
# ### 3) 중소형주 중 최근 1년 수익률 상위 100개 추출

# %%
from datetime import datetime, timedelta

# 어제 날짜 구하기
yesterday = datetime.now() - timedelta(days=1)

# YYYYMMDD 형식으로 포맷팅
formatted_date = yesterday.strftime("%Y%m%d")

print(formatted_date)  # 예: 20240321 (오늘이 2024년 3월 22일이라고 가정)

one_year_ago = (datetime.now() - timedelta(days=365)).strftime("%Y%m%d")
print(one_year_ago)
# Out:
# 20250707
# 20240708

# %%
krx_stock_info
# Out:
#          기준일자    종목코드      종목명   시장구분 소속부      종가    대비   등락률      시가      고가  \
# 0    20250707  095570   AJ네트웍스  KOSPI   -    4220   -45 -1.06    4265    4265
# 1    20250707  006840    AK홀딩스  KOSPI   -   11910  -250 -2.06   12300   12300
# 2    20250707  027410      BGF  KOSPI   -    4170    40  0.97    4140    4245
# 3    20250707  282330   BGF리테일  KOSPI   -  124600  3400  2.81  124500  126400
# 4    20250707  138930  BNK금융지주  KOSPI   -   13750   350  2.61   13610   13920
# ..        ...     ...      ...    ...  ..     ...   ...   ...     ...     ...
# 957  20250707  079980      휴비스  KOSPI   -    3330   130  4.06    3215    3380
# 958  20250707  005010      휴스틸  KOSPI   -    4690   -35 -0.74    4720    4760
# 959  20250707  000540     흥국화재  KOSPI   -    4170    20  0.48    4150    4200
# 960  20250707  000545    흥국화재우  KOSPI   -    7100  -110 -1.53    7190    7190
# 961  20250707  003280     흥아해운  KOSPI   -    1800    -5 -0.28    1766    1855
#
#          저가      거래량         거래대금           시가총액      상장주식수
# 0      4200   113351    478427775   190966642980   45252759
# 1     11900    15884    190334730   157778451510   13247561
# 2      4115   201001    841238675   399139018470   95716791
# 3    122500    40069   5007420750  2153574687600   17283906
# 4     13400   939708  12907287840  4377773386250  318383519
# ..      ...      ...          ...            ...        ...
# 957    3205   193249    641700623   114885000000   34500000
# 958    4665   332934   1564665877   263522071750   56188075
# 959    4080    51436    213315370   267891829650   64242645
# 960    7100     7971     56661710     5452800000     768000
# 961    1765  7515949  13605990742   432764818200  240424899
#
# [962 rows x 15 columns]

# %%
volume_filtered
# Out:
#           종목명  시가총액     거래량    시장구분
# 4063      지엔코   127  167374  kosdaq
# 4057     빌리언스   131  194418  kosdaq
# 4052     인베니아   141   52728  kosdaq
# 4044      더코디   149   86007  kosdaq
# 4038   비케이홀딩스   162   87205  kosdaq
# ...       ...   ...     ...     ...
# 3036       빅텍  1180  146380  kosdaq
# 3035    한빛레이저  1185  128175  kosdaq
# 3030   다산네트웍스  1186  140104  kosdaq
# 3032  한선엔지니어링  1186   91677  kosdaq
# 936      KTcs  1197  114317   kospi
#
# [525 rows x 4 columns]

# %%
# API endpoint and parameters
kospi_url = "http://data-dbg.krx.co.kr/svc/apis/sto/stk_bydd_trd"
kosdaq_url = "http://data-dbg.krx.co.kr/svc/apis/sto/ksq_bydd_trd"
params = {
    "basDd": "20250706"  # Specify the date
}

# Headers with the authentication key
headers = {
    "AUTH_KEY": "18CEC6172A764513B4C60CAA3E3186D3AE2453C3"
}

# Make the GET request
response = requests.get(kospi_url, params=params, headers=headers)

# Check the response status and process the data
if response.status_code == 200:
    data = response.json()
    if 'OutBlock_1' in data:
        krx_stock_info = pd.DataFrame(data['OutBlock_1'])

        # 컬럼명 한글로 변환
        column_map = {
            'BAS_DD': '기준일자',
            'ISU_CD': '종목코드',
            'ISU_NM': '종목명',
            'MKT_NM': '시장구분',
            'SECT_TP_NM': '소속부',
            'TDD_CLSPRC': '종가',
            'CMPPREVDD_PRC': '대비',
            'FLUC_RT': '등락률',
            'TDD_OPNPRC': '시가',
            'TDD_HGPRC': '고가',
            'TDD_LWPRC': '저가',
            'ACC_TRDVOL': '거래량',
            'ACC_TRDVAL': '거래대금',
            'MKTCAP': '시가총액',
            'LIST_SHRS': '상장주식수'
        }

        krx_stock_info = krx_stock_info.rename(columns=column_map)

        numeric_columns = ['종가', '대비', '등락률', '시가', '고가', '저가', '거래량', '거래대금', '시가총액', '상장주식수']
        
        for col in numeric_columns:
            if col in krx_stock_info.columns:
                krx_stock_info[col] = pd.to_numeric(krx_stock_info[col].str.replace(',', ''), errors='coerce')

    print("Data retrieved successfully:")
else:
    print(f"Failed to retrieve data. HTTP Status Code: {response.status_code}")
    print("Response:", response.text)
# Out:
# Data retrieved successfully:

# %%
response.text
# Out:
# '{"OutBlock_1":[]}'

# %%
krx_stock_info[krx_stock_info['종목명'].str.contains('부방', na=False)]
# Out:
#          기준일자    종목코드 종목명    시장구분    소속부    종가   대비   등락률    시가    고가    저가  \
# 425  20200414  014470  부방  KOSDAQ  우량기업부  2105  105  5.25  1995  2180  1990
#
#         거래량        거래대금          시가총액     상장주식수
# 425  656086  1378464940  126410007300  60052260

# %%
df["등락률"].iloc[0]
# Out:
# np.float64(1.54)

# %%
import requests
import pandas as pd
from datetime import datetime

def get_krx_data(base_date):
    url = "http://data-dbg.krx.co.kr/svc/apis/sto/ksq_bydd_trd"
    headers = {
        "AUTH_KEY": "18CEC6172A764513B4C60CAA3E3186D3AE2453C3"
    }
    params = {
        "basDd": base_date
    }
    
    try:
        response = requests.get(url, params=params, headers=headers)
        
        if response.status_code == 200:
            data = response.json()
            
            # OutBlock_1에서 데이터 추출
            if 'OutBlock_1' in data:
                df = pd.DataFrame(data['OutBlock_1'])
                
                # 컬럼명 한글로 변환
                column_map = {
                    'BAS_DD': '기준일자',
                    'ISU_CD': '종목코드',
                    'ISU_NM': '종목명',
                    'MKT_NM': '시장구분',
                    'SECT_TP_NM': '소속부',
                    'TDD_CLSPRC': '종가',
                    'CMPPREVDD_PRC': '대비',
                    'FLUC_RT': '등락률',
                    'TDD_OPNPRC': '시가',
                    'TDD_HGPRC': '고가',
                    'TDD_LWPRC': '저가',
                    'ACC_TRDVOL': '거래량',
                    'ACC_TRDVAL': '거래대금',
                    'MKTCAP': '시가총액',
                    'LIST_SHRS': '상장주식수'
                }
                df = df.rename(columns=column_map)
                
                # 숫자형 데이터 변환
                numeric_columns = ['종가', '대비', '등락률', '시가', '고가', '저가', 
                                 '거래량', '거래대금', '시가총액', '상장주식수']
                for col in numeric_columns:
                    df[col] = pd.to_numeric(df[col], errors='coerce')
                
                print(f"데이터 로드 완료: {len(df)}개 종목")
                return df
            else:
                print("데이터가 OutBlock_1에 없습니다.")
                return None
            
    except Exception as e:
        print(f"오류 발생: {str(e)}")
        return None

# 테스트
today = datetime.now().strftime("%Y%m%d")
df = get_krx_data(today)

if df is not None:
    # 데이터 저장
    df.to_csv('krx_data.csv', index=False, encoding='utf-8-sig')
    
    print("\n데이터 미리보기:")
    print(df.head())
    print("\n데이터 정보:")
    print(df.info())
# Out:
# 오류 발생: '종가'

# %%
KRX_API_KEY="C197A4D3002F4790A248643FE049703008D57F34"
DART_API_KEY="4758096e577a50f35eaec98b171e463367c7c23f"

# %%
merged_df['시총증감률'].describe()
# Out:
# count    332.000000
# mean      -0.095683
# std        0.280571
# min       -0.791463
# 25%       -0.271814
# 50%       -0.114901
# 75%        0.050438
# max        1.291974
# Name: 시총증감률, dtype: float64

# %%
import requests
import json

# DART API 엔드포인트 설정
url = "https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json"

# API 파라미터 설정
params = {
    'crtfc_key': DART_API_KEY,  # 위에서 정의한 API 키 사용
    'corp_code': '00126380',
    'bsns_year': '2018',
    'reprt_code': '11011',
    'fs_div': 'OFS'
}

# API 요청
response = requests.get(url, params=params)

# JSON 응답 파싱
if response.status_code == 200:
    data = response.json()
    # 데이터 확인
    print("Status:", data['status'])
    print("Message:", data['message'])
    
    # 재무제표 데이터 출력
    for item in data['list']:
        print(f"\nAccount Name: {item['account_nm']}")
        print(f"Amount: {item['thstrm_amount']} {item['currency']}")
else:
    print("Error:", response.status_code)
# Out:
# Status: 000
# Message: 정상
#
# Account Name: 유동자산
# Amount: 80039455000000 KRW
#
# Account Name: 현금및현금성자산
# Amount: 2607957000000 KRW
#
# Account Name: 단기금융상품
# Amount: 34113871000000 KRW
#
# Account Name: 매출채권
# Amount: 24933267000000 KRW
#
# Account Name: 미수금
# Amount: 1515079000000 KRW
#
# Account Name: 선급금
# Amount: 807262000000 KRW
#
# Account Name: 선급비용
# Amount: 2230628000000 KRW
#
# Account Name: 재고자산
# Amount: 12440951000000 KRW
#
# Account Name: 기타유동자산
# Amount: 1390440000000 KRW
#
# Account Name: 매각예정분류자산
# Amount:  KRW
#
# Account Name: 비유동자산
# Amount: 138981902000000 KRW
#
# Account Name: 장기매도가능금융자산
# Amount:  KRW
#
# Account Name: 기타포괄손익-공정가치금융자산
# Amount: 1098565000000 KRW
#
# Account Name: 당기손익-공정가치금융자산
# Amount: 7413000000 KRW
#
# Account Name: 종속기업, 관계기업 및 공동기업 투자
# Amount: 55959745000000 KRW
#
# Account Name: 유형자산
# Amount: 70602493000000 KRW
#
# Account Name: 무형자산
# Amount: 2901476000000 KRW
#
# Account Name: 장기선급비용
# Amount: 4108410000000 KRW
#
# Account Name: 순확정급여자산
# Amount: 562356000000 KRW
#
# Account Name: 이연법인세자산
# Amount: 654456000000 KRW
#
# Account Name: 기타비유동자산
# Amount: 3086988000000 KRW
#
# Account Name: 자산총계
# Amount: 219021357000000 KRW
#
# Account Name: 유동부채
# Amount: 43145053000000 KRW
#
# Account Name: 매입채무
# Amount: 7315631000000 KRW
#
# Account Name: 단기차입금
# Amount: 10353873000000 KRW
#
# Account Name: 미지급금
# Amount: 8385752000000 KRW
#
# Account Name: 선수금
# Amount: 214615000000 KRW
#
# Account Name: 예수금
# Amount: 572702000000 KRW
#
# Account Name: 미지급비용
# Amount: 6129837000000 KRW
#
# Account Name: 미지급법인세
# Amount: 7925887000000 KRW
#
# Account Name: 유동성장기부채
# Amount: 5440000000 KRW
#
# Account Name: 충당부채
# Amount: 2135314000000 KRW
#
# Account Name: 기타유동부채
# Amount: 106002000000 KRW
#
# Account Name: 비유동부채
# Amount: 2888179000000 KRW
#
# Account Name: 사채
# Amount: 43516000000 KRW
#
# Account Name: 장기미지급금
# Amount: 2472416000000 KRW
#
# Account Name: 장기충당부채
# Amount: 372217000000 KRW
#
# Account Name: 기타비유동부채
# Amount: 30000000 KRW
#
# Account Name: 부채총계
# Amount: 46033232000000 KRW
#
# Account Name: 자본금
# Amount: 897514000000 KRW
#
# Account Name: 우선주자본금
# Amount: 119467000000 KRW
#
# Account Name: 보통주자본금
# Amount: 778047000000 KRW
#
# Account Name: 주식발행초과금
# Amount: 4403893000000 KRW
#
# Account Name: 이익잉여금
# Amount: 166555532000000 KRW
#
# Account Name: 기타자본항목
# Amount: 1131186000000 KRW
#
# Account Name: 자본총계
# Amount: 172988125000000 KRW
#
# Account Name: 자본과부채총계
# Amount: 219021357000000 KRW
#
# Account Name: 수익(매출액)
# Amount: 170381870000000 KRW
#
# Account Name: 매출원가
# Amount: 101666506000000 KRW
#
# Account Name: 매출총이익
# Amount: 68715364000000 KRW
#
# Account Name: 판매비와관리비
# Amount: 25015913000000 KRW
#
# Account Name: 영업이익(손실)
# Amount: 43699451000000 KRW
#
# Account Name: 기타수익
# Amount: 972145000000 KRW
#
# Account Name: 기타비용
# Amount: 504562000000 KRW
#
# Account Name: 금융수익
# Amount: 3737494000000 KRW
#
# Account Name: 금융비용
# Amount: 3505673000000 KRW
#
# Account Name: 법인세비용차감전순이익(손실)
# Amount: 44398855000000 KRW
#
# Account Name: 법인세비용
# Amount: 11583728000000 KRW
#
# Account Name: 계속영업이익(손실)
# Amount: 32815127000000 KRW
#
# Account Name: 당기순이익(손실)
# Amount: 32815127000000 KRW
#
# Account Name: 기본주당이익(손실)
# Amount: 4830 KRW
#
# Account Name: 희석주당이익(손실)
# Amount: 4830 KRW
#
# Account Name: 당기순이익(손실)
# Amount: 32815127000000 KRW
#
# Account Name: 기타포괄손익
# Amount: -378321000000 KRW
#
# Account Name: 후속적으로 당기손익으로 재분류되지 않는 포괄손익
# Amount: -378321000000 KRW
#
# Account Name: 기타포괄손익-공정가치금융자산평가손익
# Amount: -88340000000 KRW
#
# Account Name: 순확정급여자산 재측정요소
# Amount: -289981000000 KRW
#
# Account Name: 후속적으로 당기손익으로 재분류되는 포괄손익
# Amount:  KRW
#
# Account Name: 매도가능금융자산평가손익
# Amount:  KRW
#
# Account Name: 총포괄손익
# Amount: 32436806000000 KRW
#
# Account Name: 영업활동 현금흐름
# Amount: 44341217000000 KRW
#
# Account Name: 영업에서 창출된 현금흐름
# Amount: 53596311000000 KRW
#
# Account Name: 당기순이익
# Amount: 32815127000000 KRW
#
# Account Name: 조정
# Amount: 27095149000000 KRW
#
# Account Name: 영업활동으로 인한 자산부채의 변동
# Amount: -6313965000000 KRW
#
# Account Name: 이자의 수취
# Amount: 459074000000 KRW
#
# Account Name: 이자의 지급
# Amount: 343270000000 KRW
#
# Account Name: 배당금 수입
# Amount: -779567000000 KRW
#
# Account Name: 법인세 납부액
# Amount: 10150465000000 KRW
#
# Account Name: 투자활동 현금흐름
# Amount: -31678548000000 KRW
#
# Account Name: 단기금융상품의 순감소(증가)
# Amount: -7203807000000 KRW
#
# Account Name: 단기매도가능금융자산의 처분
# Amount:  KRW
#
# Account Name: 장기금융상품의 처분
# Amount:  KRW
#
# Account Name: 장기금융상품의 취득
# Amount: 1860000000000 KRW
#
# Account Name: 장기매도가능금융자산의 처분
# Amount:  KRW
#
# Account Name: 장기매도가능금융자산의 취득
# Amount:  KRW
#
# Account Name: 기타포괄손익-공정가치금융자산의 처분
# Amount: 7345000000 KRW
#
# Account Name: 기타포괄손익-공정가치금융자산의 취득
# Amount: -204055000000 KRW
#
# Account Name: 당기손익-공정가치금융자산의 처분
# Amount: 7421000000 KRW
#
# Account Name: 당기손익-공정가치금융자산의 취득
# Amount: -1776000000 KRW
#
# Account Name: 종속기업, 관계기업 및 공동기업 투자의 처분
# Amount: 25846000000 KRW
#
# Account Name: 종속기업, 관계기업 및 공동기업 투자의 취득
# Amount: -520660000000 KRW
#
# Account Name: 유형자산의 처분
# Amount: 340558000000 KRW
#
# Account Name: 유형자산의 취득
# Amount: 21387378000000 KRW
#
# Account Name: 무형자산의 처분
# Amount: 706000000 KRW
#
# Account Name: 무형자산의 취득
# Amount: 880032000000 KRW
#
# Account Name: 현금의 기타유출입
# Amount: -2716000000 KRW
#
# Account Name: 재무활동 현금흐름
# Amount: -12818480000000 KRW
#
# Account Name: 단기차입금의 순증가(감소)
# Amount: -1796186000000 KRW
#
# Account Name: 자기주식의 취득
# Amount: 875111000000 KRW
#
# Account Name: 사채 및 장기차입금의 상환
# Amount: 5357000000 KRW
#
# Account Name: 배당금 지급
# Amount: 10141826000000 KRW
#
# Account Name: 외화환산으로 인한 현금의 변동
# Amount:  KRW
#
# Account Name: 현금 및 현금성자산의 증가(감소)
# Amount: -155811000000 KRW
#
# Account Name: 기초 현금 및 현금성자산
# Amount: 2763768000000 KRW
#
# Account Name: 기말 현금 및 현금성자산
# Amount: 2607957000000 KRW
#
# Account Name: 기초자본
# Amount: 4403893000000 KRW
#
# Account Name: 기초자본
# Amount: 151569775000000 KRW
#
# Account Name: 기초자본
# Amount: -4660356000000 KRW
#
# Account Name: 기초자본
# Amount:  KRW
#
# Account Name: 기초자본
# Amount: 150928724000000 KRW
#
# Account Name: 기초자본
# Amount: 897514000000 KRW
#
# Account Name: 회계정책변경누적효과
# Amount: -61021000000 KRW
#
# Account Name: 회계정책변경누적효과
# Amount: 61021000000 KRW
#
# Account Name: 수정후 기초자본
# Amount:  KRW
#
# Account Name: 수정후 기초자본
# Amount: 151569775000000 KRW
#
# Account Name: 수정후 기초자본
# Amount: 897514000000 KRW
#
# Account Name: 수정후 기초자본
# Amount: 4403893000000 KRW
#
# Account Name: 수정후 기초자본
# Amount: 150989745000000 KRW
#
# Account Name: 수정후 기초자본
# Amount: -4721377000000 KRW
#
# Account Name: 당기순이익(손실)
# Amount: 32815127000000 KRW
#
# Account Name: 당기순이익(손실)
# Amount: 32815127000000 KRW
#
# Account Name: 매도가능금융자산평가손익
# Amount:  KRW
#
# Account Name: 매도가능금융자산평가손익
# Amount:  KRW
#
# Account Name: 매도가능금융자산평가손익
# Amount:  KRW
#
# Account Name: 기타포괄손익-공정가치금융자산평가손익
# Amount: -2697000000 KRW
#
# Account Name: 기타포괄손익-공정가치금융자산평가손익
# Amount: -85643000000 KRW
#
# Account Name: 기타포괄손익-공정가치금융자산평가손익
# Amount: -88340000000 KRW
#
# Account Name: 순확정급여자산 재측정요소
# Amount: -289981000000 KRW
#
# Account Name: 순확정급여자산 재측정요소
# Amount: -289981000000 KRW
#
# Account Name: 배당
# Amount: -10143345000000 KRW
#
# Account Name: 배당
# Amount: -10143345000000 KRW
#
# Account Name: 자기주식의 취득
# Amount: -875111000000 KRW
#
# Account Name: 자기주식의 취득
# Amount: -875111000000 KRW
#
# Account Name: 자기주식의 소각
# Amount: 7103298000000 KRW
#
# Account Name: 자기주식의 소각
# Amount: -7103298000000 KRW
#
# Account Name: 기말자본
# Amount: 4403893000000 KRW
#
# Account Name: 기말자본
# Amount: 897514000000 KRW
#
# Account Name: 기말자본
# Amount: 166555532000000 KRW
#
# Account Name: 기말자본
# Amount: 172988125000000 KRW
#
# Account Name: 기말자본
# Amount: 1131186000000 KRW

# %%
import pandas as pd

# 데이터를 리스트로 변환
data_list = []
for item in data['list']:
    data_list.append({
        '계정명': item['account_nm'],
        '당기금액': item['thstrm_amount'],
        '전기금액': item['frmtrm_amount'],
        '전전기금액': item['bfefrmtrm_amount'],
        '통화': item['currency']
    })

# DataFrame 생성
df = pd.DataFrame(data_list)

# 금액 컬럼들을 숫자로 변환 (빈 문자열은 0으로 처리)
df['당기금액'] = pd.to_numeric(df['당기금액'].replace('', '0'))
df['전기금액'] = pd.to_numeric(df['전기금액'].replace('', '0'))
df['전전기금액'] = pd.to_numeric(df['전전기금액'].replace('', '0'))

# 금액을 보기 좋게 포맷팅 (단위: 백만원)
df['당기금액'] = df['당기금액'] / 1_000_000
df['전기금액'] = df['전기금액'] / 1_000_000
df['전전기금액'] = df['전전기금액'] / 1_000_000

# 결과 출력 (모든 행 표시)
pd.set_option('display.max_rows', None)
print("재무제표 데이터 (단위: 백만원)")
df
# Out:
# 재무제표 데이터 (단위: 백만원)
#                             계정명          당기금액          전기금액         전전기금액   통화
# 0                          유동자산  8.003946e+07  7.015519e+07  6.998113e+07  KRW
# 1                      현금및현금성자산  2.607957e+06  2.763768e+06  3.778371e+06  KRW
# 2                        단기금융상품  3.411387e+07  2.551006e+07  3.017066e+07  KRW
# 3                          매출채권  2.493327e+07  2.788178e+07  2.351401e+07  KRW
# 4                           미수금  1.515079e+06  2.201402e+06  2.319782e+06  KRW
# 5                           선급금  8.072620e+05  1.097598e+06  8.143000e+05  KRW
# 6                          선급비용  2.230628e+06  2.281179e+06  2.375520e+06  KRW
# 7                          재고자산  1.244095e+07  7.837144e+06  5.981634e+06  KRW
# 8                        기타유동자산  1.390440e+06  5.822570e+05  7.431630e+05  KRW
# 9                      매각예정분류자산  0.000000e+00  0.000000e+00  2.836900e+05  KRW
# 10                        비유동자산  1.389819e+08  1.280862e+08  1.048218e+08  KRW
# 11                   장기매도가능금융자산  0.000000e+00  9.733530e+05  9.139890e+05  KRW
# 12              기타포괄손익-공정가치금융자산  1.098565e+06  0.000000e+00  0.000000e+00  KRW
# 13                당기손익-공정가치금융자산  7.413000e+03  0.000000e+00  0.000000e+00  KRW
# 14         종속기업, 관계기업 및 공동기업 투자  5.595974e+07  5.567176e+07  4.874308e+07  KRW
# 15                         유형자산  7.060249e+07  6.281696e+07  4.722883e+07  KRW
# 16                         무형자산  2.901476e+06  2.827035e+06  2.891844e+06  KRW
# 17                       장기선급비용  4.108410e+06  3.031327e+06  3.507399e+06  KRW
# 18                      순확정급여자산  5.623560e+05  8.112100e+05  5.570910e+05  KRW
# 19                      이연법인세자산  6.544560e+05  5.861610e+05  1.102390e+05  KRW
# 20                      기타비유동자산  3.086988e+06  1.368365e+06  8.693600e+05  KRW
# 21                         자산총계  2.190214e+08  1.982414e+08  1.748030e+08  KRW
# 22                         유동부채  4.314505e+07  4.449508e+07  3.407612e+07  KRW
# 23                         매입채무  7.315631e+06  6.398629e+06  6.162650e+06  KRW
# 24                        단기차입금  1.035387e+07  1.222970e+07  9.061167e+06  KRW
# 25                         미지급금  8.385752e+06  9.598654e+06  7.635740e+06  KRW
# 26                          선수금  2.146150e+05  2.140070e+05  2.004450e+05  KRW
# 27                          예수금  5.727020e+05  5.007400e+05  3.895280e+05  KRW
# 28                        미지급비용  6.129837e+06  6.657674e+06  6.284646e+06  KRW
# 29                       미지급법인세  7.925887e+06  6.565781e+06  2.055829e+06  KRW
# 30                      유동성장기부채  5.440000e+03  5.201000e+03  5.854000e+03  KRW
# 31                         충당부채  2.135314e+06  2.273688e+06  2.221717e+06  KRW
# 32                       기타유동부채  1.060020e+05  5.100900e+04  5.854600e+04  KRW
# 33                        비유동부채  2.888179e+06  2.176501e+06  3.180075e+06  KRW
# 34                           사채  4.351600e+04  4.680800e+04  5.854200e+04  KRW
# 35                       장기미지급금  2.472416e+06  1.750379e+06  2.808460e+06  KRW
# 36                       장기충당부채  3.722170e+05  3.792010e+05  3.124670e+05  KRW
# 37                      기타비유동부채  3.000000e+01  1.130000e+02  6.060000e+02  KRW
# 38                         부채총계  4.603323e+07  4.667158e+07  3.725620e+07  KRW
# 39                          자본금  8.975140e+05  8.975140e+05  8.975140e+05  KRW
# 40                       우선주자본금  1.194670e+05  1.194670e+05  1.194670e+05  KRW
# 41                       보통주자본금  7.780470e+05  7.780470e+05  7.780470e+05  KRW
# 42                      주식발행초과금  4.403893e+06  4.403893e+06  4.403893e+06  KRW
# 43                        이익잉여금  1.665555e+08  1.509287e+08  1.407476e+08  KRW
# 44                       기타자본항목  1.131186e+06 -4.660356e+06 -8.502219e+06  KRW
# 45                         자본총계  1.729881e+08  1.515698e+08  1.375468e+08  KRW
# 46                      자본과부채총계  2.190214e+08  1.982414e+08  1.748030e+08  KRW
# 47                      수익(매출액)  1.703819e+08  1.619150e+08  1.339472e+08  KRW
# 48                         매출원가  1.016665e+08  1.013997e+08  9.729064e+07  KRW
# 49                        매출총이익  6.871536e+07  6.051535e+07  3.665656e+07  KRW
# 50                      판매비와관리비  2.501591e+07  2.565826e+07  2.300912e+07  KRW
# 51                     영업이익(손실)  4.369945e+07  3.485709e+07  1.364744e+07  KRW
# 52                         기타수익  9.721450e+05  2.767967e+06  2.185600e+06  KRW
# 53                         기타비용  5.045620e+05  1.065014e+06  1.289594e+06  KRW
# 54                         금융수익  3.737494e+06  4.075602e+06  5.803751e+06  KRW
# 55                         금융비용  3.505673e+06  4.102094e+06  5.622119e+06  KRW
# 56              법인세비용차감전순이익(손실)  4.439886e+07  3.653355e+07  1.472507e+07  KRW
# 57                        법인세비용  1.158373e+07  7.732715e+06  3.145325e+06  KRW
# 58                   계속영업이익(손실)  3.281513e+07  2.880084e+07  1.157975e+07  KRW
# 59                    당기순이익(손실)  3.281513e+07  2.880084e+07  1.157975e+07  KRW
# 60                   기본주당이익(손실)  4.830000e-03  4.178000e-03  1.632000e-03  KRW
# 61                   희석주당이익(손실)  4.830000e-03  4.178000e-03  1.632000e-03  KRW
# 62                    당기순이익(손실)  3.281513e+07  2.880084e+07  1.157975e+07  KRW
# 63                       기타포괄손익 -3.783210e+05  3.197240e+05  3.080570e+05  KRW
# 64   후속적으로 당기손익으로 재분류되지 않는 포괄손익 -3.783210e+05  3.499500e+05  7.296340e+05  KRW
# 65          기타포괄손익-공정가치금융자산평가손익 -8.834000e+04  0.000000e+00  0.000000e+00  KRW
# 66                순확정급여자산 재측정요소 -2.899810e+05  3.499500e+05  7.296340e+05  KRW
# 67      후속적으로 당기손익으로 재분류되는 포괄손익  0.000000e+00 -3.022600e+04 -4.215770e+05  KRW
# 68                 매도가능금융자산평가손익  0.000000e+00 -3.022600e+04 -4.215770e+05  KRW
# 69                        총포괄손익  3.243681e+07  2.912056e+07  1.188781e+07  KRW
# 70                    영업활동 현금흐름  4.434122e+07  3.890619e+07  2.398480e+07  KRW
# 71                영업에서 창출된 현금흐름  5.359631e+07  4.135047e+07  2.490146e+07  KRW
# 72                        당기순이익  3.281513e+07  2.880084e+07  1.157975e+07  KRW
# 73                           조정  2.709515e+07  1.801298e+07  1.491009e+07  KRW
# 74           영업활동으로 인한 자산부채의 변동 -6.313965e+06 -5.463342e+06 -1.588378e+06  KRW
# 75                       이자의 수취  4.590740e+05  4.915010e+05  6.221180e+05  KRW
# 76                       이자의 지급  3.432700e+05  2.653640e+05  2.080100e+05  KRW
# 77                       배당금 수입 -7.795670e+05 -1.118779e+06 -9.037580e+05  KRW
# 78                      법인세 납부액  1.015046e+07  3.789197e+06  2.234526e+06  KRW
# 79                    투자활동 현금흐름 -3.167855e+07 -2.811881e+07 -1.424045e+07  KRW
# 80              단기금융상품의 순감소(증가) -7.203807e+06  2.960592e+06 -1.407068e+06  KRW
# 81               단기매도가능금융자산의 처분  0.000000e+00  0.000000e+00  3.010003e+06  KRW
# 82                   장기금융상품의 처분  0.000000e+00  1.700000e+06  7.000000e+05  KRW
# 83                   장기금융상품의 취득  1.860000e+06  5.000000e+05  1.700000e+06  KRW
# 84               장기매도가능금융자산의 처분  0.000000e+00  9.826500e+04  6.925470e+05  KRW
# 85               장기매도가능금융자산의 취득  0.000000e+00  1.637650e+05  4.777440e+05  KRW
# 86          기타포괄손익-공정가치금융자산의 처분  7.345000e+03  0.000000e+00  0.000000e+00  KRW
# 87          기타포괄손익-공정가치금융자산의 취득 -2.040550e+05  0.000000e+00  0.000000e+00  KRW
# 88            당기손익-공정가치금융자산의 처분  7.421000e+03  0.000000e+00  0.000000e+00  KRW
# 89            당기손익-공정가치금융자산의 취득 -1.776000e+03  0.000000e+00  0.000000e+00  KRW
# 90     종속기업, 관계기업 및 공동기업 투자의 처분  2.584600e+04  1.438362e+06  2.416678e+06  KRW
# 91     종속기업, 관계기업 및 공동기업 투자의 취득 -5.206600e+05 -7.492843e+06 -4.648008e+06  KRW
# 92                     유형자산의 처분  3.405580e+05  2.440330e+05  3.352880e+05  KRW
# 93                     유형자산의 취득  2.138738e+07  2.564123e+07  1.216108e+07  KRW
# 94                     무형자산의 처분  7.060000e+02  4.560000e+02  6.357000e+03  KRW
# 95                     무형자산의 취득  8.800320e+05  8.430960e+05  1.046676e+06  KRW
# 96                    현금의 기타유출입 -2.716000e+03  8.041900e+04  3.925700e+04  KRW
# 97                    재무활동 현금흐름 -1.281848e+07 -1.180199e+07 -9.037006e+06  KRW
# 98               단기차입금의 순증가(감소) -1.796186e+06  3.300611e+06  1.737871e+06  KRW
# 99                     자기주식의 취득  8.751110e+05  8.350424e+06  7.707938e+06  KRW
# 100              사채 및 장기차입금의 상환  5.357000e+03  6.043000e+03  5.860000e+03  KRW
# 101                      배당금 지급  1.014183e+07  6.746131e+06  3.061079e+06  KRW
# 102            외화환산으로 인한 현금의 변동  0.000000e+00  0.000000e+00  8.063000e+03  KRW
# 103          현금 및 현금성자산의 증가(감소) -1.558110e+05 -1.014603e+06  7.154110e+05  KRW
# 104               기초 현금 및 현금성자산  2.763768e+06  3.778371e+06  3.062960e+06  KRW
# 105               기말 현금 및 현금성자산  2.607957e+06  2.763768e+06  3.778371e+06  KRW
# 106                        기초자본  4.403893e+06  4.403893e+06  4.403893e+06  KRW
# 107                        기초자본  1.515698e+08  1.375468e+08  1.364283e+08  KRW
# 108                        기초자본 -4.660356e+06 -8.502219e+06 -1.252613e+07  KRW
# 109                        기초자본  0.000000e+00  0.000000e+00  2.379700e+04  KRW
# 110                        기초자본  1.509287e+08  1.407476e+08  1.436292e+08  KRW
# 111                        기초자본  8.975140e+05  8.975140e+05  8.975140e+05  KRW
# 112                  회계정책변경누적효과 -6.102100e+04  0.000000e+00  0.000000e+00  KRW
# 113                  회계정책변경누적효과  6.102100e+04  0.000000e+00  0.000000e+00  KRW
# 114                    수정후 기초자본  0.000000e+00  0.000000e+00  2.379700e+04  KRW
# 115                    수정후 기초자본  1.515698e+08  1.375468e+08  1.364283e+08  KRW
# 116                    수정후 기초자본  8.975140e+05  8.975140e+05  8.975140e+05  KRW
# 117                    수정후 기초자본  4.403893e+06  4.403893e+06  4.403893e+06  KRW
# 118                    수정후 기초자본  1.509897e+08  1.407476e+08  1.436292e+08  KRW
# 119                    수정후 기초자본 -4.721377e+06 -8.502219e+06 -1.252613e+07  KRW
# 120                   당기순이익(손실)  3.281513e+07  2.880084e+07  1.157975e+07  KRW
# 121                   당기순이익(손실)  3.281513e+07  2.880084e+07  1.157975e+07  KRW
# 122                매도가능금융자산평가손익  0.000000e+00  0.000000e+00 -2.379700e+04  KRW
# 123                매도가능금융자산평가손익  0.000000e+00 -3.022600e+04 -4.215770e+05  KRW
# 124                매도가능금융자산평가손익  0.000000e+00 -3.022600e+04 -3.977800e+05  KRW
# 125         기타포괄손익-공정가치금융자산평가손익 -2.697000e+03  0.000000e+00  0.000000e+00  KRW
# 126         기타포괄손익-공정가치금융자산평가손익 -8.564300e+04  0.000000e+00  0.000000e+00  KRW
# 127         기타포괄손익-공정가치금융자산평가손익 -8.834000e+04  0.000000e+00  0.000000e+00  KRW
# 128               순확정급여자산 재측정요소 -2.899810e+05  3.499500e+05  7.296340e+05  KRW
# 129               순확정급여자산 재측정요소 -2.899810e+05  3.499500e+05  7.296340e+05  KRW
# 130                          배당 -1.014334e+07 -6.747124e+06 -3.061361e+06  KRW
# 131                          배당 -1.014334e+07 -6.747124e+06 -3.061361e+06  KRW
# 132                    자기주식의 취득 -8.751110e+05 -8.350424e+06 -7.707938e+06  KRW
# 133                    자기주식의 취득 -8.751110e+05 -8.350424e+06 -7.707938e+06  KRW
# 134                    자기주식의 소각  7.103298e+06  1.187256e+07  1.139999e+07  KRW
# 135                    자기주식의 소각 -7.103298e+06 -1.187256e+07 -1.139999e+07  KRW
# 136                        기말자본  4.403893e+06  4.403893e+06  4.403893e+06  KRW
# 137                        기말자본  8.975140e+05  8.975140e+05  8.975140e+05  KRW
# 138                        기말자본  1.665555e+08  1.509287e+08  1.407476e+08  KRW
# 139                        기말자본  1.729881e+08  1.515698e+08  1.375468e+08  KRW
# 140                        기말자본  1.131186e+06 -4.660356e+06 -8.502219e+06  KRW

# %%
import pandas as pd

# 데이터를 리스트로 변환
data_list = []
for item in data['list']:
    # 재무상태표 항목만 선택 (sj_div가 'BS'인 항목)
    if item['sj_div'] == 'BS':
        data_list.append({
            '계정명': item['account_nm'],
            '당기금액': item['thstrm_amount'],
            '전기금액': item['frmtrm_amount'],
            '전전기금액': item['bfefrmtrm_amount'],
            '통화': item['currency']
        })

# DataFrame 생성
df = pd.DataFrame(data_list)

# 금액 컬럼들을 숫자로 변환 (빈 문자열은 0으로 처리)
df['당기금액'] = pd.to_numeric(df['당기금액'].replace('', '0'))
df['전기금액'] = pd.to_numeric(df['전기금액'].replace('', '0'))
df['전전기금액'] = pd.to_numeric(df['전전기금액'].replace('', '0'))

# 금액을 보기 좋게 포맷팅 (단위: 백만원)
df['당기금액'] = df['당기금액'] / 1_000_000
df['전기금액'] = df['전기금액'] / 1_000_000
df['전전기금액'] = df['전전기금액'] / 1_000_000

# 결과 출력 (모든 행 표시)
pd.set_option('display.max_rows', None)
print("\n재무상태표 데이터 (단위: 백만원)")
display(df)

# 손익계산서 데이터 추출
income_list = []
for item in data['list']:
    # 손익계산서 항목만 선택 (sj_div가 'IS'인 항목)
    if item['sj_div'] == 'IS':
        income_list.append({
            '계정명': item['account_nm'],
            '당기금액': item['thstrm_amount'],
            '전기금액': item['frmtrm_amount'],
            '전전기금액': item['bfefrmtrm_amount'],
            '통화': item['currency']
        })

# DataFrame 생성
df_income = pd.DataFrame(income_list)

# 금액 컬럼들을 숫자로 변환 (빈 문자열은 0으로 처리)
df_income['당기금액'] = pd.to_numeric(df_income['당기금액'].replace('', '0'))
df_income['전기금액'] = pd.to_numeric(df_income['전기금액'].replace('', '0'))
df_income['전전기금액'] = pd.to_numeric(df_income['전전기금액'].replace('', '0'))

# 금액을 보기 좋게 포맷팅 (단위: 백만원)
df_income['당기금액'] = df_income['당기금액'] / 1_000_000
df_income['전기금액'] = df_income['전기금액'] / 1_000_000
df_income['전전기금액'] = df_income['전전기금액'] / 1_000_000

print("\n손익계산서 데이터 (단위: 백만원)")
display(df_income)
# Out:
# 재무상태표 데이터 (단위: 백만원)
#                      계정명         당기금액         전기금액        전전기금액   통화
# 0                   유동자산   80039455.0   70155189.0   69981128.0  KRW
# 1               현금및현금성자산    2607957.0    2763768.0    3778371.0  KRW
# 2                 단기금융상품   34113871.0   25510064.0   30170656.0  KRW
# 3                   매출채권   24933267.0   27881777.0   23514012.0  KRW
# 4                    미수금    1515079.0    2201402.0    2319782.0  KRW
# 5                    선급금     807262.0    1097598.0     814300.0  KRW
# 6                   선급비용    2230628.0    2281179.0    2375520.0  KRW
# 7                   재고자산   12440951.0    7837144.0    5981634.0  KRW
# 8                 기타유동자산    1390440.0     582257.0     743163.0  KRW
# 9               매각예정분류자산          0.0          0.0     283690.0  KRW
# 10                 비유동자산  138981902.0  128086171.0  104821831.0  KRW
# 11            장기매도가능금융자산          0.0     973353.0     913989.0  KRW
# 12       기타포괄손익-공정가치금융자산    1098565.0          0.0          0.0  KRW
# 13         당기손익-공정가치금융자산       7413.0          0.0          0.0  KRW
# 14  종속기업, 관계기업 및 공동기업 투자   55959745.0   55671759.0   48743079.0  KRW
# 15                  유형자산   70602493.0   62816961.0   47228830.0  KRW
# 16                  무형자산    2901476.0    2827035.0    2891844.0  KRW
# 17                장기선급비용    4108410.0    3031327.0    3507399.0  KRW
# 18               순확정급여자산     562356.0     811210.0     557091.0  KRW
# 19               이연법인세자산     654456.0     586161.0     110239.0  KRW
# 20               기타비유동자산    3086988.0    1368365.0     869360.0  KRW
# 21                  자산총계  219021357.0  198241360.0  174802959.0  KRW
# 22                  유동부채   43145053.0   44495084.0   34076122.0  KRW
# 23                  매입채무    7315631.0    6398629.0    6162650.0  KRW
# 24                 단기차입금   10353873.0   12229701.0    9061167.0  KRW
# 25                  미지급금    8385752.0    9598654.0    7635740.0  KRW
# 26                   선수금     214615.0     214007.0     200445.0  KRW
# 27                   예수금     572702.0     500740.0     389528.0  KRW
# 28                 미지급비용    6129837.0    6657674.0    6284646.0  KRW
# 29                미지급법인세    7925887.0    6565781.0    2055829.0  KRW
# 30               유동성장기부채       5440.0       5201.0       5854.0  KRW
# 31                  충당부채    2135314.0    2273688.0    2221717.0  KRW
# 32                기타유동부채     106002.0      51009.0      58546.0  KRW
# 33                 비유동부채    2888179.0    2176501.0    3180075.0  KRW
# 34                    사채      43516.0      46808.0      58542.0  KRW
# 35                장기미지급금    2472416.0    1750379.0    2808460.0  KRW
# 36                장기충당부채     372217.0     379201.0     312467.0  KRW
# 37               기타비유동부채         30.0        113.0        606.0  KRW
# 38                  부채총계   46033232.0   46671585.0   37256197.0  KRW
# 39                   자본금     897514.0     897514.0     897514.0  KRW
# 40                우선주자본금     119467.0     119467.0     119467.0  KRW
# 41                보통주자본금     778047.0     778047.0     778047.0  KRW
# 42               주식발행초과금    4403893.0    4403893.0    4403893.0  KRW
# 43                 이익잉여금  166555532.0  150928724.0  140747574.0  KRW
# 44                기타자본항목    1131186.0   -4660356.0   -8502219.0  KRW
# 45                  자본총계  172988125.0  151569775.0  137546762.0  KRW
# 46               자본과부채총계  219021357.0  198241360.0  174802959.0  KRW
# 손익계산서 데이터 (단위: 백만원)
#                 계정명          당기금액          전기금액         전전기금액   통화
# 0           수익(매출액)  1.703819e+08  1.619150e+08  1.339472e+08  KRW
# 1              매출원가  1.016665e+08  1.013997e+08  9.729064e+07  KRW
# 2             매출총이익  6.871536e+07  6.051535e+07  3.665656e+07  KRW
# 3           판매비와관리비  2.501591e+07  2.565826e+07  2.300912e+07  KRW
# 4          영업이익(손실)  4.369945e+07  3.485709e+07  1.364744e+07  KRW
# 5              기타수익  9.721450e+05  2.767967e+06  2.185600e+06  KRW
# 6              기타비용  5.045620e+05  1.065014e+06  1.289594e+06  KRW
# 7              금융수익  3.737494e+06  4.075602e+06  5.803751e+06  KRW
# 8              금융비용  3.505673e+06  4.102094e+06  5.622119e+06  KRW
# 9   법인세비용차감전순이익(손실)  4.439886e+07  3.653355e+07  1.472507e+07  KRW
# 10            법인세비용  1.158373e+07  7.732715e+06  3.145325e+06  KRW
# 11       계속영업이익(손실)  3.281513e+07  2.880084e+07  1.157975e+07  KRW
# 12        당기순이익(손실)  3.281513e+07  2.880084e+07  1.157975e+07  KRW
# 13       기본주당이익(손실)  4.830000e-03  4.178000e-03  1.632000e-03  KRW
# 14       희석주당이익(손실)  4.830000e-03  4.178000e-03  1.632000e-03  KRW

# %%
def get_value(df, account_name):
    """특정 계정의 당기 금액을 반환하는 함수"""
    try:
        return df[df['계정명'] == account_name]['당기금액'].values[0]
    except:
        return 0

# 재무비율 계산
당기순이익 = get_value(df_income, '당기순이익(손실)')
자본총계 = get_value(df, '자본총계')
자산총계 = get_value(df, '자산총계')
부채총계 = get_value(df, '부채총계')

# ROE (자기자본이익률) = 당기순이익 / 자기자본 * 100
ROE = (당기순이익 / 자본총계) * 100

# ROA (총자산이익률) = 당기순이익 / 총자산 * 100
ROA = (당기순이익 / 자산총계) * 100

# 부채비율 = 부채총계 / 자본총계 * 100
부채비율 = (부채총계 / 자본총계) * 100

# PER과 PBR은 주가 정보가 필요하므로 KRX API나 다른 소스에서 가져와야 합니다
# 여기서는 계산 방법만 주석으로 표시
# PER = 주가 / 주당순이익(EPS)
# PBR = 주가 / 주당순자산(BPS)

print("\n=== 재무비율 분석 ===")
print(f"ROE (자기자본이익률): {ROE:.2f}%")
print(f"ROA (총자산이익률): {ROA:.2f}%")
print(f"부채비율: {부채비율:.2f}%")

# 데이터프레임으로도 만들어보기
import pandas as pd

ratios = pd.DataFrame({
    '비율': ['ROE (자기자본이익률)', 'ROA (총자산이익률)', '부채비율'],
    '값': [ROE, ROA, 부채비율],
    '단위': ['%', '%', '%']
})

display(ratios)
# Out:
# === 재무비율 분석 ===
# ROE (자기자본이익률): 18.97%
# ROA (총자산이익률): 14.98%
# 부채비율: 26.61%
#               비율          값 단위
# 0  ROE (자기자본이익률)  18.969584  %
# 1   ROA (총자산이익률)  14.982615  %
# 2           부채비율  26.610631  %

# %%
# KRX API를 통해 주가 정보 가져오기
import requests

# KRX API 엔드포인트 (예시)
krx_url = "http://data.krx.co.kr/comm/bldAttendant/getJsonData.cmd"

# 삼성전자 종목코드
stock_code = "005930"  # 삼성전자

# API 파라미터
params = {
    'bld': 'dbms/MDC/STAT/standard/MDCSTAT01501',
    'locale': 'ko_KR',
    'tboxisuCd_finder_stkisu0_0': stock_code,
    'isuCd': 'KR7' + stock_code + '00006',
    'share': '1',
    'money': '1',
    'csvxls_isNo': 'false'
}

try:
    response = requests.get(krx_url, params=params)
    if response.status_code == 200:
        stock_data = response.json()
        # 주가 데이터 처리
        # 실제 응답 구조에 따라 적절히 수정 필요
        current_price = stock_data.get('주가', 0)  # 예시
        
        # 주당순이익(EPS) 계산
        발행주식수 = get_value(df, '발행주식수')  # 실제 데이터에 있는지 확인 필요
        EPS = 당기순이익 / 발행주식수 if 발행주식수 != 0 else 0
        
        # 주당순자산(BPS) 계산
        BPS = 자본총계 / 발행주식수 if 발행주식수 != 0 else 0
        
        # PER, PBR 계산
        PER = current_price / EPS if EPS != 0 else 0
        PBR = current_price / BPS if BPS != 0 else 0
        
        # 기존 비율 데이터프레임에 추가
        new_ratios = pd.DataFrame({
            '비율': ['PER (주가수익비율)', 'PBR (주가순자산비율)'],
            '값': [PER, PBR],
            '단위': ['배', '배']
        })
        
        ratios = pd.concat([ratios, new_ratios], ignore_index=True)
        display(ratios)
        
except Exception as e:
    print(f"주가 정보를 가져오는데 실패했습니다: {e}")
    print("PER과 PBR은 주가 정보가 필요하므로 계산할 수 없습니다.")
